# %%
import matplotlib.pyplot as plt

# %%
# Combine all the data into a single dictionary
all_data = {
    'happy_50iter': {
        '0': 4.72, '1': 4.7, '2': 4.74, '3': 4.7, '4': 4.72, '5': 4.66, '6': 4.66, '7': 4.7, '8': 4.68, '9': 4.68,
        '10': 4.66, '11': 4.68, '12': 4.66, '13': 4.66, '14': 4.66, '15': 4.7, '16': 4.68, '17': 4.66, '18': 4.72, '19': 4.66,
        '20': 4.66, '21': 4.7, '22': 4.72, '23': 4.68, '24': 4.68, '25': 4.7, '26': 4.7, '27': 4.68, '28': 4.68, '29': 4.76,
        '30': 4.68, '31': 4.72, '32': 4.66, '33': 4.68, '34': 4.7, '35': 4.7, '36': 4.74, '37': 4.72, '38': 4.76, '39': 4.78,
        '40': 4.72, '41': 4.74, '42': 4.72, '43': 4.72, '44': 4.7, '45': 4.72, '46': 4.74, '47': 4.76, '48': 4.72, '49': 4.74,
        '50': 4.76
    },
    'happy_1iter': {'0': 4.46, '1': 4.12},
    'happy_5iter': {'0': 4.58, '1': 4.44,
  '2': 4.44,
  '3': 4.54,
  '4': 4.44,
  '5': 4.56},
  'happy_10iter': {
  '0': 4.76,
  '1': 4.62,
  '2': 4.74,
  '3': 4.78,
  '4': 4.78,
  '5': 4.72,
  '6': 4.76,
  '7': 4.66,
  '8': 4.64,
  '9': 4.64,
  '10': 4.72}
}

# Plot each line
for label, data in all_data.items():
    x_values = list(map(int, data.keys()))
    y_values = list(data.values())
    plt.plot(x_values, y_values, label=label)

# Set y-axis limits
plt.ylim(0, 5)

# Add labels and title
plt.xlabel('Step')
plt.ylabel('The extent of happiness')
plt.title('Line Chart Example')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
# Combine all the data into a single dictionary
all_data = {
    "single_step": {'0': 80.69013959914446, '-0.1': 75.5598055422306, '-0.2': 76.98275662958622, '-0.3': 73.51949802972376, '-0.4': 72.76768777146935},
    # "02": {'0': 4.84, '1': 4.64}
}

# Plot each line
for label, data in all_data.items():
    x_values = list(map(int, data.keys()))
    y_values = list(data.values())
    plt.plot(x_values, y_values, label=label)

# Set y-axis limits
plt.ylim(0, 5)

# Add labels and title
plt.xlabel('Step')
plt.ylabel('Value')
plt.title('Line Chart Example')

# Show legend
plt.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 9
#       7 # Plot each line
#       8 for label, data in all_data.items():
# ----> 9     x_values = list(map(int, data.keys()))
#      10     y_values = list(data.values())
#      11     plt.plot(x_values, y_values, label=label)
#
# ValueError: invalid literal for int() with base 10: '-0.1'

# %%
# Combine all the data into a single dictionary
all_data = {
    "batchsize=1": {'-0.4': 72.13, '-0.6': 67.55, '-1': 60.25, '-5': 55.15},
    "batchsize=4": {'-0.2': 76.01, '-0.3': 76.69, '-0.4': 77.19, '-0.5': 77.40,
                    '-0.6': 76.26, '-0.7': 76.94, '-1': 76.63, '-2': 69.85, '-5': 58.36},
    "batchsize=5": {'-0.5': 75.55, '-0.6': 76.62, '-0.7': 75.77, '-1': 76.49,
                    '-2': 73.02, '-3': 69.62, '-5': 63.19}
    # "02": {'0': 4.84, '1': 4.64}
}

# Plot each line
for label, data in all_data.items():
    x_values = list(map(float, data.keys()))
    y_values = list(data.values())
    plt.plot(x_values, y_values, label=label, marker='o', markersize=3)

# Set y-axis limits
plt.ylim(50, 90)

# Add labels and title
plt.xlabel('Step Size')
plt.ylabel('Happiness')
plt.title('Effects of different batch sizes')

# Show legend
plt.legend()

plt.savefig('/home/cmin/LLM-Interpretation-Playground/charts/batch_study.pdf')

# Show the plot
plt.show()

# %%
# Smoothing
# Combine all the data into a single dictionary
all_data = {
    "batchsize=1;step_size=-0.4": {'0': 72.13, '0.001': 72.59, '0.005': 73.49, '0.01': 73.29,
    '0.02': 72.63, '0.05': 71.24, '0.08': 74.85, '0.1': 73.29,},
    # "02": {'0': 4.84, '1': 4.64}
}

# Plot each line
for label, data in all_data.items():
    x_values = list(map(float, data.keys()))
    y_values = list(data.values())
    plt.plot(x_values, y_values, label=label, marker='o', markersize=3)

# Set y-axis limits
plt.ylim(50, 90)

# Add labels and title
plt.xlabel('Smoothing Factor')
plt.ylabel('Hapiness')
plt.title('Study on smoothing factor')

# Show legend
plt.legend()

# Show the plot
plt.show()

# %%
# Searching
all_data = {
    "consistent;bz=2;cf=-1": {0: 80.17, 1: 67.81, 2: 63.82, 3: 61.80, 4: 63.06, 5: 60.93},
    "inconsistent;bz=2;cf=-1": {0: 80.17, 1: 67.79, 2: 68.63, 3: 60.00, 4: 62.39, 5: 65.93},
    "consistent;bz=5;cf=-1": {0: 79.02, 1: 70.26, 2: 69.51, 3: 70.67, 4: 70.95, 5: 70.88},
    "consistent;bz=5;cf=-2":{0: 79.02, 1: 69.34, 2: 68.21, 3: 65.49, 4: 65.41, 5: 65.25},
    "consistent;bz=5;cf=-3": {0: 79.02, 1: 67.85, 2: 65.68, 3: 64.32, 4: 64.32, 5: 63.50},
    "consistent;bz=5;cf=-3;smooth=-0.05": {0: 79.02, 1: 73.86, 2: 66.56, 3: 63.24, 4: 63.38, 5: 59.40}
    # "02": {'0': 4.84, '1': 4.64}
}

# Plot each line
for label, data in all_data.items():
    x_values = list(map(int, data.keys()))
    y_values = list(data.values())
    plt.plot(x_values, y_values, label=label)

# Set y-axis limits
plt.ylim(50, 90)

# Add labels and title
plt.xlabel('Iterations')
plt.ylabel('Happiness')
plt.title('Study on Search')

# Show legend
plt.legend()

# Show the plot
plt.show()
